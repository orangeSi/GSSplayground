# %%
import fire

# %%
def test(A:str, B:int):
    print (f"{A} type is {type(A)}")
    print (f"{B} type is {type(B)}")

# %%
test("1","3")
# Out:
# 1 type is <class 'str'>
# 3 type is <class 'str'>
